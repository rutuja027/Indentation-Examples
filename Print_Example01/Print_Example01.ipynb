# %%
print("This is a really long line, but we can make it across multiple lines.")
# Out:
# This is a really long line, but we can make it across multiple lines.

# %%
print("This s a really long line,", \
    "but we can make it across multiple lines.")
# Out:
# This s a really long line, but we can make it across multiple lines.
