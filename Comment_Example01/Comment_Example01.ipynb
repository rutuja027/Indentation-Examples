# %% [markdown]
# # This is incorrect(Overflowing comment copied from PDF)

# %%
# Import all the required elements to split a dataset, as well as the
load_digits function from scikit-learn to load the digits dataset

from sklearn.datasets import load_digits
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
# Out:
#   File "<ipython-input-1-485843ae221e>", line 2
#     load_digits function from scikit-learn to load the digits dataset
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # This is correct (A Multiline comment copied from PDF)

# %%
"""
Import all the required elements to split a dataset, as well as the
load_digits function from scikit-learn to load the digits dataset
"""
from sklearn.datasets import load_digits
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

# %%
digits = load_digits()

# %%
X = pd.DataFrame(digits.data)
Y = pd.DataFrame(digits.target)
print(X.shape, Y.shape)
# Out:
# (1797, 64) (1797, 1)
